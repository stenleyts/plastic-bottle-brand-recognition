# %%
# ======================================
# 1. Setup awal
# ======================================
from google.colab import drive
drive.mount('/content/drive')

import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Path dataset di Google Drive
dataset_dir = '/content/drive/MyDrive/dataset'
# Out:
# Mounted at /content/drive

# %%
# ======================================
# 2. Preprocessing dataset
# ======================================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 480 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
# ======================================
# 3. Membangun model CNN
# ======================================
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# ======================================
# 4. Training model
# ======================================
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=15
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 251s 16s/step - accuracy: 0.3218 - loss: 1.1959 - val_accuracy: 0.4583 - val_loss: 1.1187
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.5802 - loss: 0.8948 - val_accuracy: 0.5667 - val_loss: 1.6552
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.6842 - loss: 0.7181 - val_accuracy: 0.5750 - val_loss: 1.6529
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.6940 - loss: 0.6250 - val_accuracy: 0.5250 - val_loss: 1.9932
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.7466 - loss: 0.5359 - val_accuracy: 0.5833 - val_loss: 1.6319
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.7697 - loss: 0.4909 - val_accuracy: 0.6083 - val_loss: 1.9268
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.8117 - loss: 0.4784 - val_accuracy: 0.5583 - val_loss: 1.7413
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.8285 - loss: 0.3772 - val_accuracy: 0.6250 - val_loss: 1.7514
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8383 - loss: 0.3391 - val_accuracy: 0.6167 - val_loss: 1.6366
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.8710 - loss: 0.3291 - val_accuracy: 0.6333 - val_loss: 1.9612
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.9046 - loss: 0.2683 - val_accuracy: 0.6167 - val_loss: 2.0704
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.9150 - loss: 0.2208 - val_accuracy: 0.5917 - val_loss: 2.2563
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.9340 - loss: 0.1765 - val_accuracy: 0.6417 - val_loss: 2.0561
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.9103 - loss: 0.2050 - val_accuracy: 0.6583 - val_loss: 2.1405
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.9143 - loss: 0.2389 - val_accuracy: 0.5750 - val_loss: 3.7696

# %%
# ======================================
# 5. Simpan model ke Google Drive
# ======================================
model_save_path = '/content/drive/MyDrive/bottle_classifier.h5'
model.save(model_save_path)
print("Model saved to:", model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved to: /content/drive/MyDrive/bottle_classifier.h5
